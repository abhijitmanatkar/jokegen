# %%
from datasets import Dataset
from transformers import Trainer
from transformers import AutoModelForMaskedLM, DistilBertForMaskedLM
from transformers import AutoTokenizer, DistilBertTokenizer
from transformers import DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
model_checkpoint = "distilbert-base-cased"
model = DistilBertForMaskedLM.from_pretrained(model_checkpoint)
tokenizer = DistilBertTokenizer.from_pretrained(model_checkpoint, do_lower_case=False)

# %%
SEED = 0
BATCH_SIZE = 16
LEARNING_RATE = 2e-5 
LR_WARMUP_STEPS = 100
WEIGHT_DECAY = 0.01

# %% [markdown]
# ### Dataset prep

# %%
with open('train.txt', 'r') as f:
    lines = f.readlines()
    
df = pd.DataFrame({"text": [line for line in lines]})
df_train, df_valid = train_test_split(
    df, test_size=0.15, random_state=SEED
)

train_dataset = Dataset.from_pandas(df_train[['text']].dropna())
valid_dataset = Dataset.from_pandas(df_valid[['text']].dropna())

# %%
def tokenize_function(row):
    return tokenizer(
        row['text'],
        padding='max_length',
        return_special_tokens_mask=True)
  
column_names = dataset.column_names

train_dataset = train_dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=column_names,
)

valid_dataset = valid_dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=column_names,
)
# Out:
#   0%|          | 0/182 [00:00<?, ?ba/s]
#   0%|          | 0/33 [00:00<?, ?ba/s]

# %%
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.15
)
steps_per_epoch = int(len(train_dataset) / BATCH_SIZE)

training_args = TrainingArguments(
    output_dir='./distilbert-joke',
    logging_dir='./LMlogs',             
    num_train_epochs=2,
    do_train=True,
    do_eval=True,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    warmup_steps=LR_WARMUP_STEPS,
    # save_steps=steps_per_epoch,
    weight_decay=WEIGHT_DECAY,
    learning_rate=LEARNING_RATE, 
    evaluation_strategy='steps',
    save_strategy='steps',
    eval_steps=1000,
    save_steps=1000,
    load_best_model_at_end=True,
    metric_for_best_model='loss', 
    greater_is_better=False,
    seed=SEED
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    tokenizer=tokenizer,
)

trainer.train()
trainer.save_model("./finetuned-distilbert/")
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# /home2/abhijit.manatkar/miniconda3/envs/advnlp/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 181718
#   Num Epochs = 2
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 22716
#   Number of trainable parameters = 65812036
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='22716' max='22716' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [22716/22716 4:26:59, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>1.477800</td>
#       <td>2.481643</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.342200</td>
#       <td>2.192749</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.264600</td>
#       <td>2.145570</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.251600</td>
#       <td>2.096352</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.152700</td>
#       <td>2.073568</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.154100</td>
#       <td>2.033172</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>2.095900</td>
#       <td>2.010656</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>2.100900</td>
#       <td>1.987986</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>2.074800</td>
#       <td>1.953148</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>2.054900</td>
#       <td>1.941496</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>2.054500</td>
#       <td>1.934346</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.951800</td>
#       <td>1.903291</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>1.964600</td>
#       <td>1.910410</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>1.955600</td>
#       <td>1.897327</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>1.953900</td>
#       <td>1.883693</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>1.926000</td>
#       <td>1.880451</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>1.944000</td>
#       <td>1.872434</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>1.930400</td>
#       <td>1.850006</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>1.940700</td>
#       <td>1.846011</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>1.903800</td>
#       <td>1.834665</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>1.866800</td>
#       <td>1.844338</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>1.921500</td>
#       <td>1.824429</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-1000
# Configuration saved in ./distilbert-joke/checkpoint-1000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-1000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-2000
# Configuration saved in ./distilbert-joke/checkpoint-2000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-2000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-3000
# Configuration saved in ./distilbert-joke/checkpoint-3000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-3000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-4000
# Configuration saved in ./distilbert-joke/checkpoint-4000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-4000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-5000
# Configuration saved in ./distilbert-joke/checkpoint-5000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-5000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-6000
# Configuration saved in ./distilbert-joke/checkpoint-6000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-6000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-7000
# Configuration saved in ./distilbert-joke/checkpoint-7000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-7000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-8000
# Configuration saved in ./distilbert-joke/checkpoint-8000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-8000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-9000
# Configuration saved in ./distilbert-joke/checkpoint-9000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-9000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-10000
# Configuration saved in ./distilbert-joke/checkpoint-10000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-10000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-11000
# Configuration saved in ./distilbert-joke/checkpoint-11000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-11000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-12000
# Configuration saved in ./distilbert-joke/checkpoint-12000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-12000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-13000
# Configuration saved in ./distilbert-joke/checkpoint-13000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-13000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-14000
# Configuration saved in ./distilbert-joke/checkpoint-14000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-14000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-15000
# Configuration saved in ./distilbert-joke/checkpoint-15000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-15000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-16000
# Configuration saved in ./distilbert-joke/checkpoint-16000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-16000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-17000
# Configuration saved in ./distilbert-joke/checkpoint-17000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-17000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-18000
# Configuration saved in ./distilbert-joke/checkpoint-18000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-18000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-19000
# Configuration saved in ./distilbert-joke/checkpoint-19000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-19000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-20000
# Configuration saved in ./distilbert-joke/checkpoint-20000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-20000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-21000
# Configuration saved in ./distilbert-joke/checkpoint-21000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-21000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMaskedLM.forward` and have been ignored: __index_level_0__, special_tokens_mask. If __index_level_0__, special_tokens_mask are not expected by `DistilBertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 32068
#   Batch size = 16
# Saving model checkpoint to ./distilbert-joke/checkpoint-22000
# Configuration saved in ./distilbert-joke/checkpoint-22000/config.json
# Model weights saved in ./distilbert-joke/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in ./distilbert-joke/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in ./distilbert-joke/checkpoint-22000/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./distilbert-joke/checkpoint-22000 (score: 1.8244292736053467).
# Saving model checkpoint to ./finetuned-distilbert/
# Configuration saved in ./finetuned-distilbert/config.json
# Model weights saved in ./finetuned-distilbert/pytorch_model.bin
# tokenizer config file saved in ./finetuned-distilbert/tokenizer_config.json
# Special tokens file saved in ./finetuned-distilbert/special_tokens_map.json
